# %% [markdown]
# ## Connecting to Database

# %%
# %reload_ext sql

from sqlalchemy import create_engine

# %sql postgresql://augur:password@ec2-3-135-196-178.us-east-2.compute.amazonaws.com:5432/augur

# %% [markdown]
# ## SQL Query

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     augur_data.contributors
# WHERE
#     cntrb_hireable = 't'
# Out:
#  * postgresql://augur:***@ec2-3-135-196-178.us-east-2.compute.amazonaws.com:5432/augur
# 4 rows affected.
# ...
